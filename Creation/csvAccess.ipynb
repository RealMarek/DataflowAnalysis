# %%
import pandas as pd

# %%
df_base = pd.read_csv("../Data/Köln/baseLinks.csv")
df_base
# Out:
#                                                 links
# 0                           Charlie Barnett (Komiker)
# 1                                     Conrad Voelcker
# 2                    Westminster Kennel Club Dog Show
# 3                                                WHTZ
# 4                   Internationales Hot-Dog-Wettessen
# ..                                                ...
# 95                                       Max Lortzing
# 96           Liste der Krankenhäuser in New York City
# 97  International Alliance of Theatrical Stage Emp...
# 98                                      Madge Jenison
# 99                            Michael Blake (Musiker)
#
# [100 rows x 1 columns]

# %%
df_structure = pd.read_csv("../Data/Köln/structure.csv")
df_structure
# Out:
#                         base                               link      type
# 0         Mohsen Fachrisadeh                            Teheran  outgoing
# 1         Mohsen Fachrisadeh                 Benjamin Netanyahu  outgoing
# 2         Mohsen Fachrisadeh         Iranische Revolutionsgarde  outgoing
# 3         Mohsen Fachrisadeh                             Physik  outgoing
# 4         Mohsen Fachrisadeh                  Nachrichtendienst  outgoing
# ...                      ...                                ...       ...
# 55519  James D. Melville Jr.                 Rechtswissenschaft  outgoing
# 55520  James D. Melville Jr.  Präsident der Vereinigten Staaten  outgoing
# 55521  James D. Melville Jr.                               1957  outgoing
# 55522  James D. Melville Jr.                  Russische Sprache  outgoing
# 55523  James D. Melville Jr.                 Rutgers University  outgoing
#
# [55524 rows x 3 columns]

# %%
df_structure.loc[df_structure['base'].isin(df_base["links"])].to_csv("../Data/Köln/importantStructure.csv", index=False)

# %%
df_incoming = df_structure.loc[df_structure['link'].isin(df_base["links"])]
df_incoming
# Out:
#                                                     base  \
# 1136   Beziehungen zwischen der Ukraine und den Verei...
# 2509                                     Bernard Addison
# 3136                                      Shelley Hirsch
# 5635                              Die den Hals riskieren
# 7788                                        Kevin Norton
# ...                                                  ...
# 52983                                      Hagar Ben-Ari
# 53374                                   Henry John Heinz
# 53770                              Aaliyah Dana Haughton
# 53811                                     Amy Vanderbilt
# 54458                                       T. J. Stiles
#
#                        link      type
# 1136         William Safire  outgoing
# 2509       Small’s Paradise  outgoing
# 3136               Brooklyn  outgoing
# 5635         Bonnie Bedelia  outgoing
# 7788               Brooklyn  outgoing
# ...                     ...       ...
# ...

# %%
df_incoming = df_incoming.rename(columns={"base":"link","link":"base"})
df_incoming
# Out:
#                        base  \
# 1136         William Safire
# 2509       Small’s Paradise
# 3136               Brooklyn
# 5635         Bonnie Bedelia
# 7788               Brooklyn
# ...                     ...
# 52983              Brooklyn
# 53374       Frederick Trump
# 53770              Brooklyn
# 53811  Cornelius Vanderbilt
# 54458  Cornelius Vanderbilt
#
#                                                     link      type
# 1136   Beziehungen zwischen der Ukraine und den Verei...  outgoing
# 2509                                     Bernard Addison  outgoing
# 3136                                      Shelley Hirsch  outgoing
# 5635                              Die den Hals riskieren  outgoing
# 7788                                        Kevin Norton  outgoing
# ...                                                  ...       ...
# 52983                                      Hagar Ben-Ari  outgoing
# 53374                                   Henry John Heinz  outgoing
# ...

# %%
df_incoming["type"] = "incoming"
df_incoming.to_csv("../Data/Köln/importantStructure.csv",index=False,mode='a')

# %% [markdown]
# ## Create Data for all important Links

# %%
important_df = pd.read_csv("../Data/Köln/importantLinks.csv")
important_df
# Out:
#                                        link
# 0             FIFA-Weltfußballer des Jahres
# 1                                   Komiker
# 2                                   Teterow
# 3                            Milton Babbitt
# 4                               Tony Curtis
# ...                                     ...
# 2184              Kalifornischer Goldrausch
# 2185                                 Quasar
# 2186                 New York (Bundesstaat)
# 2187  Massachusetts Institute of Technology
# 2188                      COVID-19-Pandemie
#
# [2189 rows x 1 columns]

# %%
import requests

def getPageViews(name):
    address = "https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/de.wikipedia.org/all-access/user/" + name + "/daily/20230701/20231001"
    # Personal username for identification for the Wikipedia API
    headers = {'User-Agent': 'marek.seipel@web.de'}
    resp = requests.get(address, headers=headers)
    details = resp.json()
    return [{"date": e["timestamp"], "views": e["views"]} for e in details["items"]]

def savePageViews(position, link, date, views, first):
    data = pd.DataFrame({
        "link": link,
        "date": date,
        "views": views
    })
    data.to_csv(position,mode="a",index=False,header=first)

# %%
for i,titel in enumerate(important_df["link"]):
    views = getPageViews(titel)
        if i == 0:
            savePageViews("../Data/Köln/views.csv",titel,v["date"],v["views"],True)
        else:
            savePageViews("../Data/Köln/views.csv",titel,v["date"],v["views"],False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31504/4104637588.py in <module>
#       3     for v in views:
#       4         if i == 0:
# ----> 5             savePageViews("../Data/Köln/views.csv",e,v["date"],v["views"],True)
#       6         else:
#       7             savePageViews("../Data/Köln/views.csv",e,v["date"],v["views"],False)
#
# ~\AppData\Local\Temp/ipykernel_31504/171119269.py in savePageViews(position, link, date, views, first)
#      10
#      11 def savePageViews(position, link, date, views, first):
# ---> 12     data = pd.DataFrame({
#      13         "link": link,
#      14         "date": date,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
# ...
