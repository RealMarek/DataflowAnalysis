# %%
import urllib3
from bs4 import BeautifulSoup
import re  
import requests


def getOrderedLinks(wikipage):
    http = urllib3.PoolManager()
    response = http.request("GET", wikipage)
    soup = BeautifulSoup(response.data)
    soup = soup.find(id="mw-content-text")#
    link_list = soup.find_all("a",href=re.compile("/wiki/"))
    return link_list

def getIncomingLinks(wikipage):
    S = requests.Session()
    URL = "https://de.wikipedia.org/w/api.php"
    PARAMS = {
        "action": "query",
        "format": "json",
        "list": "backlinks",
        "bltitle": wikipage,
        "bllimit": 500,
        "pldir" : "descending"
    }
    R = S.get(url=URL, params=PARAMS)
    DATA = R.json()
    BACKLINKS = DATA["query"]["backlinks"]
    return BACKLINKS
    
def cutIncomingLinks(incoming_links, base_link):
    output = []
    for link in incoming_links:
        all_links = getOrderedLinks(link)
        if(all_links.index(base_link) < 30):
            output.append(link)
    return output

def filterLinks(soup):
    reg = re.compile("^(?!/wiki/Datei:).+")
    reg2 = re.compile("^(?!/wiki/Spezial:).+")
    reg3 = re.compile("^/wiki")
    filteredList = [e for e in soup if reg.match(e["href"]) and reg2.match(e["href"]) and reg3.match(e["href"])]
    return filteredList

def cutList(linkList, length):
    return linkList[:length]

def requestClickData(linkList):
    out = dict()
    for i in linkList:
        out[i["title"]] = wikiPageView(i["title"])
    return out    

def wikiPageView(name):
    address = "https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/de.wikipedia.org/all-access/user/" + name + "/daily/20230701/20231001"
    # Personal username for identification for the Wikipedia API
    headers = {'User-Agent': 'marek.seipel@web.de'}
    resp = requests.get(address, headers=headers)
    details = resp.json()
    return details

def saveLinks(link_list):
    print("not implemented yet")

    
    
#format for each base article: one json file
#
def savePageview(pageview_list):
    print("not implemented yet")

# %%
#link = "https://de.wikipedia.org/wiki/Gazastreifen"
#tagList = getOrderedLinks(link)
#filteredList = filterLinks(tagList)
#cuttedList = cutList(filteredList,30)
#allData = requestClickData(cuttedList)

# %%
allData
# Out:
# {'Staat': {'items': [{'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023070100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 262},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023070200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 307},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023070300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 313},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023070400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 335},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023070500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 330},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023070600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 243},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023070700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 282},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023070800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 288},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023070900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 283},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023071000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 337},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023071100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 360},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023071200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 319},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023071300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 255},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023071400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 319},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023071500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 246},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023071600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 298},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023071700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 316},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023071800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 270},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023071900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 300},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023072000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 285},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023072100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 265},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023072200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 252},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023072300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 267},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023072400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 314},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023072500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 298},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023072600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 274},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023072700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 286},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023072800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 265},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023072900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 304},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023073000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 317},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023073100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 285},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023080100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 281},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023080200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 275},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023080300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 275},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023080400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 273},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023080500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 265},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023080600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 291},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023080700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 339},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023080800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 274},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023080900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 283},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023081000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 313},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023081100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 295},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023081200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 276},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023081300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 250},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023081400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 332},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023081500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 428},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023081600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 411},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023081700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 353},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023081800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 265},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023081900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 232},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023082000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 295},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023082100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 371},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023082200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 310},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023082300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 324},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023082400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 355},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023082500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 291},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023082600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 240},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023082700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 289},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023082800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 329},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023082900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 340},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023083000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 357},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023083100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 327},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023090100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 296},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023090200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 231},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023090300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 298},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023090400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 286},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023090500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 426},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023090600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 360},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023090700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 336},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023090800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 322},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023090900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 270},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023091000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 270},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023091100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 387},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023091200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 340},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023091300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 383},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023091400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 356},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023091500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 306},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023091600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 292},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023091700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 296},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023091800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 418},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023091900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 381},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023092000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 364},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023092100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 343},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023092200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 338},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023092300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 305},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023092400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 275},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023092500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 383},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023092600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 378},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023092700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 335},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023092800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 331},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023092900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 336},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023093000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 246},
#    {'project': 'de.wikipedia',
#     'article': 'Staat',
#     'granularity': 'daily',
#     'timestamp': '2023100100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 275}]},
#  'Staat Palästina': {'items': [{'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023070100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 680},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023070200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 675},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023070300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1664},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023070400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2059},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023070500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1369},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023070600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 930},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023070700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 833},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023070800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 658},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023070900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 838},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023071000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 775},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023071100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 788},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023071200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 836},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023071300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 719},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023071400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 624},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023071500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 591},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023071600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 849},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023071700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 980},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023071800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 830},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023071900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 747},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023072000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 632},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023072100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 648},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023072200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 705},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023072300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 724},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023072400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 827},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023072500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 870},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023072600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 747},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023072700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 696},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023072800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 660},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023072900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 679},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023073000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 775},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023073100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 746},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023080100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 787},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023080200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 691},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023080300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 661},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023080400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 645},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023080500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 632},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023080600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 791},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023080700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 832},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023080800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 626},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023080900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 630},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023081000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 586},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023081100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 547},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023081200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 503},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023081300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 699},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023081400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 640},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023081500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 847},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023081600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 745},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023081700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 671},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023081800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 666},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023081900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 610},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023082000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 669},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023082100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 666},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023082200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 684},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023082300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 683},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023082400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 606},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023082500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 744},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023082600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 591},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023082700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 745},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023082800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 701},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023082900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 684},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023083000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 574},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023083100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 646},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023090100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 564},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023090200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 481},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023090300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 537},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023090400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 537},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023090500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 643},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023090600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 627},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023090700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 599},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023090800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 554},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023090900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 493},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023091000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 617},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023091100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 663},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023091200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 855},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023091300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1067},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023091400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 725},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023091500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 675},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023091600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 675},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023091700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 707},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023091800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 742},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023091900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 731},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023092000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 652},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023092100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 685},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023092200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 612},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023092300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 600},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023092400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 634},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023092500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 616},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023092600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 692},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023092700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 604},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023092800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 674},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023092900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 509},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023093000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 505},
#    {'project': 'de.wikipedia',
#     'article': 'Staat_Palästina',
#     'granularity': 'daily',
#     'timestamp': '2023100100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 612}]},
#  'Flächeninhalt': {'items': [{'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023070100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 103},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023070200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 109},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023070300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 130},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023070400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 124},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023070500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 115},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023070600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 84},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023070700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 99},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023070800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 78},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023070900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 108},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023071000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 100},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023071100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 119},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023071200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 130},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023071300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 118},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023071400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 92},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023071500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 86},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023071600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 114},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023071700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 90},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023071800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 109},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023071900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 84},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023072000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 95},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023072100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 68},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023072200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 99},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023072300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 107},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023072400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 117},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023072500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 98},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023072600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 98},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023072700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 84},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023072800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 93},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023072900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 63},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023073000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 71},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023073100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 92},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023080100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 69},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023080200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 77},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023080300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 65},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023080400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 87},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023080500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 75},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023080600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 101},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023080700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 91},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023080800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 79},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023080900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 92},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023081000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 88},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023081100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 85},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023081200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 80},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023081300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 110},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023081400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 111},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023081500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 82},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023081600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 104},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023081700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 112},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023081800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 83},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023081900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 84},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023082000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 95},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023082100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 116},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023082200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 122},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023082300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 109},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023082400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 92},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023082500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 105},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023082600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 79},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023082700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 100},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023082800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 121},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023082900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 129},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023083000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 136},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023083100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 101},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023090100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 90},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023090200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 79},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023090300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 114},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023090400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 119},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023090500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 150},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023090600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 101},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
#     'granularity': 'daily',
#     'timestamp': '2023090700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 138},
#    {'project': 'de.wikipedia',
#     'article': 'Flächeninhalt',
# ...
#    {'project': 'de.wikipedia',
#     'article': 'Landwirtschaft',
#     'granularity': 'daily',
#     'timestamp': '2023092600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 193},
#    {'project': 'de.wikipedia',
#     'article': 'Landwirtschaft',
#     'granularity': 'daily',
#     'timestamp': '2023092700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 209},
#    {'project': 'de.wikipedia',
#     'article': 'Landwirtschaft',
#     'granularity': 'daily',
#     'timestamp': '2023092800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 180},
#    {'project': 'de.wikipedia',
#     'article': 'Landwirtschaft',
#     'granularity': 'daily',
#     'timestamp': '2023092900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 132},
#    {'project': 'de.wikipedia',
#     'article': 'Landwirtschaft',
#     'granularity': 'daily',
#     'timestamp': '2023093000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 88},
#    {'project': 'de.wikipedia',
#     'article': 'Landwirtschaft',
#     'granularity': 'daily',
#     'timestamp': '2023100100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 124}]},
#  'Abu Auda': {'items': [{'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023070100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023070200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023070300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023070400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023070500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 4},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023070600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023070700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 4},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023070800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023070900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 3},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023071000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023071100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 4},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023071200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023071300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023071400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023071500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023071600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023071700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023071800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023071900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023072000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023072100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023072200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023072400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023072500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023072600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023072700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023072800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 5},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023072900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023073000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023080100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023080200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023080300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 5},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023080500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023080600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 4},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023080700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023080800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023081000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023081100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023081200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023081300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023081400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023081500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023081700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023081800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023081900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023082000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023082100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023082200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023082300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023082400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023082500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023082700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023082800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023082900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023083000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023083100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023090100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023090200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023090300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023090400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023090500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023090600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023090700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023090800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023090900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023091000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023091100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023091300',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023091500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023091700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 3},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023091800',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023092000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023092100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023092200',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023092400',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023092500',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 1},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023092600',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023092700',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 0},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023092900',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023093000',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 2},
#    {'project': 'de.wikipedia',
#     'article': 'Abu_Auda',
#     'granularity': 'daily',
#     'timestamp': '2023100100',
#     'access': 'all-access',
#     'agent': 'user',
#     'views': 3}]}}

# %%
import json 
with open('convert.txt', 'w') as convert_file: 
     convert_file.write(json.dumps(allData))

# %%
reducedData = dict()
for key, value in allData.items():
    reducedData[key] = []
    for item in value["items"]:
        for key2, value2 in item.items():
            if key2 == "views":
                reducedData[key].append(value2)

# %%
reducedData
# Out:
# {'Staat': [262,
#   307,
#   313,
#   335,
#   330,
#   243,
#   282,
#   288,
#   283,
#   337,
#   360,
#   319,
#   255,
#   319,
#   246,
#   298,
#   316,
#   270,
#   300,
#   285,
#   265,
#   252,
#   267,
#   314,
#   298,
#   274,
#   286,
#   265,
#   304,
#   317,
#   285,
#   281,
#   275,
#   275,
#   273,
#   265,
#   291,
#   339,
#   274,
#   283,
#   313,
#   295,
#   276,
#   250,
#   332,
#   428,
#   411,
#   353,
#   265,
#   232,
#   295,
#   371,
#   310,
#   324,
#   355,
#   291,
#   240,
#   289,
#   329,
#   340,
#   357,
#   327,
#   296,
#   231,
#   298,
#   286,
#   426,
#   360,
#   336,
#   322,
#   270,
#   270,
#   387,
#   340,
#   383,
#   356,
#   306,
#   292,
#   296,
#   418,
#   381,
#   364,
#   343,
#   338,
#   305,
#   275,
#   383,
#   378,
#   335,
#   331,
#   336,
#   246,
#   275],
#  'Staat Palästina': [680,
#   675,
#   1664,
#   2059,
#   1369,
#   930,
#   833,
#   658,
#   838,
#   775,
#   788,
#   836,
#   719,
#   624,
#   591,
#   849,
#   980,
#   830,
#   747,
#   632,
#   648,
#   705,
#   724,
#   827,
#   870,
#   747,
#   696,
#   660,
#   679,
#   775,
#   746,
#   787,
#   691,
#   661,
#   645,
#   632,
#   791,
#   832,
#   626,
#   630,
#   586,
#   547,
#   503,
#   699,
#   640,
#   847,
#   745,
#   671,
#   666,
#   610,
#   669,
#   666,
#   684,
#   683,
#   606,
#   744,
#   591,
#   745,
#   701,
#   684,
#   574,
#   646,
#   564,
#   481,
#   537,
#   537,
#   643,
#   627,
#   599,
#   554,
#   493,
#   617,
#   663,
#   855,
#   1067,
#   725,
#   675,
#   675,
#   707,
#   742,
#   731,
#   652,
#   685,
#   612,
#   600,
#   634,
#   616,
#   692,
#   604,
#   674,
#   509,
#   505,
#   612],
#  'Flächeninhalt': [103,
#   109,
#   130,
#   124,
#   115,
#   84,
#   99,
#   78,
#   108,
#   100,
#   119,
#   130,
#   118,
#   92,
#   86,
#   114,
#   90,
#   109,
#   84,
#   95,
#   68,
#   99,
#   107,
#   117,
#   98,
#   98,
#   84,
#   93,
#   63,
#   71,
#   92,
#   69,
#   77,
#   65,
#   87,
#   75,
#   101,
#   91,
#   79,
#   92,
#   88,
#   85,
#   80,
#   110,
#   111,
#   82,
#   104,
#   112,
#   83,
#   84,
#   95,
#   116,
#   122,
#   109,
#   92,
#   105,
#   79,
#   100,
#   121,
#   129,
#   136,
#   101,
#   90,
#   79,
#   114,
#   119,
#   150,
#   101,
#   138,
#   104,
#   95,
#   116,
#   136,
#   140,
#   108,
#   158,
#   90,
#   87,
#   118,
#   142,
#   156,
#   143,
#   131,
#   117,
#   105,
#   148,
#   162,
#   147,
#   153,
#   123,
#   97,
#   73,
#   113],
#  'Einwohner': [127,
#   136,
#   152,
#   133,
#   131,
#   104,
#   97,
#   132,
#   149,
#   106,
#   140,
#   127,
#   116,
#   117,
#   126,
#   158,
#   135,
#   112,
#   115,
#   111,
#   106,
#   126,
#   146,
#   122,
#   120,
#   93,
#   117,
#   109,
#   124,
#   139,
#   110,
#   130,
#   118,
#   151,
#   267,
#   97,
#   135,
#   99,
#   125,
#   140,
#   110,
#   128,
#   125,
#   128,
#   131,
#   159,
#   154,
#   122,
#   110,
#   127,
#   159,
#   165,
#   148,
#   128,
#   123,
#   149,
#   130,
#   143,
#   144,
#   125,
#   130,
#   127,
#   125,
#   100,
#   131,
#   191,
#   156,
#   113,
#   140,
#   107,
#   122,
#   133,
#   131,
#   134,
#   138,
#   143,
#   92,
#   108,
#   142,
#   151,
#   135,
#   140,
#   119,
#   149,
#   138,
#   128,
#   127,
#   127,
#   135,
#   111,
#   133,
#   104,
#   160],
#  'Bevölkerungsdichte': [431,
#   480,
#   489,
#   458,
#   399,
#   402,
#   404,
#   480,
#   457,
#   429,
#   434,
#   441,
#   417,
#   375,
#   388,
#   468,
#   439,
#   422,
#   440,
#   450,
#   398,
#   410,
#   487,
#   476,
#   475,
#   493,
#   408,
#   428,
#   467,
#   557,
#   517,
#   760,
#   582,
#   510,
#   433,
#   426,
#   517,
#   492,
#   475,
#   472,
#   475,
#   473,
#   466,
#   499,
#   485,
#   512,
#   472,
#   447,
#   449,
#   383,
#   529,
#   490,
#   487,
#   506,
#   455,
#   456,
#   407,
#   493,
#   505,
#   436,
#   509,
#   464,
#   384,
#   386,
#   490,
#   750,
#   496,
#   472,
#   461,
#   426,
#   463,
#   532,
#   456,
#   474,
#   446,
#   463,
#   426,
#   461,
#   508,
#   452,
#   473,
#   504,
#   469,
#   450,
#   418,
#   466,
#   477,
#   496,
#   394,
#   417,
#   441,
#   416,
#   474],
#  'ISO 3166-2': [33,
#   36,
#   75,
#   85,
#   89,
#   98,
#   49,
#   33,
#   42,
#   91,
#   77,
#   96,
#   79,
#   69,
#   23,
#   29,
#   77,
#   81,
#   87,
#   63,
#   68,
#   35,
#   29,
#   76,
#   81,
#   93,
#   96,
#   57,
#   25,
#   31,
#   89,
#   103,
#   72,
#   112,
#   77,
#   41,
#   45,
#   102,
#   75,
#   66,
#   88,
#   50,
#   23,
#   34,
#   86,
#   80,
#   100,
#   90,
#   40,
#   33,
#   36,
#   94,
#   94,
#   76,
#   90,
#   69,
#   38,
#   34,
#   76,
#   91,
#   68,
#   84,
#   53,
#   38,
#   19,
#   62,
#   65,
#   88,
#   67,
#   82,
#   31,
#   32,
#   57,
#   82,
#   99,
#   85,
#   48,
#   19,
#   36,
#   103,
#   109,
#   95,
#   95,
#   85,
#   26,
#   31,
#   78,
#   87,
#   85,
#   81,
#   54,
#   32,
#   38],
#  'ISO 3166-2:PS': [2,
#   2,
#   9,
#   1,
#   0,
#   3,
#   0,
#   0,
#   0,
#   3,
#   1,
#   2,
#   2,
#   3,
#   1,
#   1,
#   3,
#   3,
#   3,
#   0,
#   1,
#   2,
#   6,
#   5,
#   1,
#   1,
#   5,
#   3,
#   0,
#   3,
#   2,
#   2,
#   1,
#   4,
#   0,
#   2,
#   1,
#   0,
#   1,
#   2,
#   2,
#   0,
#   3,
#   1,
#   4,
#   3,
#   1,
#   0,
#   1,
#   3,
#   3,
#   3,
#   3,
#   4,
#   1,
#   2,
#   3,
#   2,
#   3,
#   3,
#   4,
#   0,
#   2,
#   0,
#   5,
#   1,
#   0,
#   0,
#   2,
#   4,
#   2,
#   2,
#   1,
#   1,
#   1,
#   0,
#   1,
#   1,
#   7,
#   1,
#   0,
#   2,
#   2,
#   2,
#   1,
#   2,
#   1,
#   3],
#  'Arabische Sprache': [445,
#   414,
#   433,
#   464,
#   493,
#   408,
#   427,
#   393,
#   468,
#   431,
#   425,
#   445,
#   484,
#   507,
#   447,
#   443,
#   463,
#   454,
#   454,
#   422,
#   399,
#   492,
#   515,
#   484,
#   530,
#   416,
#   457,
#   395,
#   450,
#   467,
#   503,
#   453,
#   397,
#   443,
#   417,
#   378,
#   448,
#   457,
#   492,
#   418,
#   383,
#   418,
#   377,
#   438,
#   425,
#   426,
#   522,
#   458,
#   399,
#   361,
#   421,
#   442,
#   443,
#   468,
#   466,
#   501,
#   398,
#   426,
#   431,
#   458,
#   348,
#   393,
#   414,
#   405,
#   394,
#   419,
#   418,
#   432,
#   421,
#   380,
#   446,
#   502,
#   491,
#   537,
#   481,
#   506,
#   431,
#   460,
#   448,
#   482,
#   501,
#   477,
#   444,
#   457,
#   376,
#   445,
#   439,
#   494,
#   444,
#   442,
#   389,
#   386,
#   395],
#  'DIN 31635': [215,
#   237,
#   218,
#   227,
#   180,
#   197,
#   197,
#   230,
#   237,
#   342,
#   193,
#   193,
#   206,
#   205,
#   296,
#   260,
#   271,
#   254,
#   221,
#   211,
#   224,
#   219,
#   269,
#   234,
#   341,
#   217,
#   220,
#   224,
#   234,
#   270,
#   244,
#   225,
#   244,
#   254,
#   217,
#   223,
#   244,
#   219,
#   271,
#   238,
#   224,
#   229,
#   295,
#   294,
#   214,
#   284,
#   251,
#   230,
#   229,
#   241,
#   260,
#   227,
#   268,
#   196,
#   224,
#   215,
#   225,
#   299,
#   240,
#   228,
#   238,
#   200,
#   298,
#   361,
#   315,
#   269,
#   243,
#   210,
#   236,
#   217,
#   340,
#   337,
#   325,
#   298,
#   286,
#   261,
#   236,
#   293,
#   328,
#   272,
#   334,
#   303,
#   280,
#   260,
#   235,
#   278,
#   233,
#   229,
#   230,
#   261,
#   244,
#   237,
#   301],
#  'Hebräische Sprache': [303,
#   294,
#   324,
#   374,
#   303,
#   282,
#   284,
#   280,
#   318,
#   286,
#   311,
#   286,
#   297,
#   302,
#   276,
#   372,
#   273,
#   291,
#   304,
#   274,
#   309,
#   291,
#   399,
#   363,
#   416,
#   377,
#   291,
#   311,
#   306,
#   409,
#   354,
#   380,
#   345,
#   289,
#   320,
#   280,
#   499,
#   318,
#   290,
#   278,
#   290,
#   266,
#   250,
#   302,
#   257,
#   368,
#   322,
#   320,
#   309,
#   308,
#   324,
#   311,
#   289,
#   360,
#   340,
#   327,
#   447,
#   394,
#   325,
#   350,
#   306,
#   296,
#   303,
#   242,
#   348,
#   309,
#   358,
#   290,
#   263,
#   314,
#   271,
#   306,
#   306,
#   319,
#   349,
#   356,
#   283,
#   303,
#   317,
#   385,
#   343,
#   285,
#   318,
#   288,
#   305,
#   299,
#   315,
#   349,
#   318,
#   374,
#   298,
#   316,
#   350],
#  'Mittelmeer': [706,
#   765,
#   721,
#   698,
#   705,
#   678,
#   589,
#   616,
#   803,
#   675,
#   684,
#   694,
#   741,
#   709,
#   736,
#   774,
#   832,
#   784,
#   835,
#   708,
#   700,
#   962,
#   1171,
#   915,
#   1093,
#   1021,
#   1386,
#   923,
#   762,
#   823,
#   710,
#   724,
#   694,
#   799,
#   759,
#   649,
#   807,
#   837,
#   783,
#   732,
#   670,
#   646,
#   782,
#   743,
#   807,
#   768,
#   648,
#   834,
#   645,
#   686,
#   785,
#   766,
#   722,
#   726,
#   694,
#   678,
#   640,
#   872,
#   741,
#   656,
#   661,
#   664,
#   611,
#   579,
#   783,
#   698,
#   741,
#   834,
#   724,
#   699,
#   694,
#   796,
#   763,
#   905,
#   923,
#   807,
#   705,
#   683,
#   801,
#   814,
#   931,
#   710,
#   676,
#   654,
#   619,
#   707,
#   672,
#   569,
#   586,
#   649,
#   618,
#   678,
#   690],
#  'Israel': [2526,
#   2037,
#   2975,
#   3461,
#   2780,
#   1892,
#   1607,
#   1730,
#   2821,
#   2096,
#   2511,
#   2033,
#   1914,
#   1745,
#   1720,
#   2578,
#   2588,
#   2688,
#   2649,
#   1696,
#   1701,
#   2207,
#   3803,
#   4708,
#   4121,
#   2734,
#   1966,
#   1748,
#   1915,
#   2945,
#   1949,
#   1989,
#   1845,
#   1788,
#   1564,
#   1587,
#   1980,
#   1768,
#   1550,
#   1567,
#   1423,
#   1274,
#   1381,
#   1975,
#   1401,
#   1925,
#   2060,
#   2312,
#   1920,
#   1583,
#   1791,
#   1549,
#   1490,
#   1946,
#   1492,
#   2175,
#   2023,
#   2063,
#   1830,
#   1744,
#   1446,
#   1548,
#   1375,
#   1414,
#   1594,
#   1591,
#   1967,
#   1686,
#   1470,
#   1297,
#   1606,
#   1947,
#   1643,
#   2252,
#   2101,
#   1567,
#   1434,
#   1324,
#   1718,
#   1891,
#   1652,
#   1612,
#   1508,
#   1558,
#   1505,
#   2025,
#   1717,
#   1593,
#   1416,
#   1736,
#   1401,
#   1437,
#   2264],
#  'Ägypten': [1488,
#   1768,
#   2024,
#   1802,
#   1564,
#   1370,
#   1288,
#   1332,
#   1464,
#   1507,
#   1476,
#   1377,
#   1343,
#   1171,
#   1315,
#   1428,
#   1548,
#   1381,
#   1370,
#   1297,
#   1342,
#   1275,
#   1438,
#   1383,
#   1539,
#   1339,
#   1614,
#   1477,
#   1310,
#   1377,
#   1434,
#   1562,
#   1399,
#   1500,
#   1440,
#   1224,
#   1471,
#   1431,
#   1316,
#   1675,
#   1237,
#   1167,
#   1292,
#   1369,
#   1727,
#   1354,
#   1249,
#   1200,
#   1162,
#   1229,
#   1397,
#   1381,
#   1420,
#   1258,
#   2438,
#   1900,
#   1351,
#   1598,
#   1319,
#   1510,
#   1845,
#   1388,
#   1225,
#   1157,
#   1267,
#   1350,
#   1585,
#   1361,
#   1375,
#   1373,
#   1529,
#   1565,
#   1540,
#   2638,
#   2074,
#   1876,
#   1396,
#   1311,
#   1674,
#   1625,
#   1539,
#   1532,
#   1525,
#   1576,
#   1540,
#   1640,
#   1612,
#   1554,
#   1422,
#   1424,
#   1405,
#   1461,
#   1923],
#  'Gaza (Stadt)': [53,
#   74,
#   115,
#   164,
#   127,
#   95,
#   60,
#   72,
#   96,
#   69,
#   70,
#   84,
#   53,
#   64,
#   51,
#   77,
#   71,
#   98,
#   72,
#   89,
#   71,
#   59,
#   74,
#   100,
#   92,
#   70,
#   59,
#   66,
#   72,
#   85,
#   90,
#   68,
#   74,
#   68,
#   68,
#   70,
#   93,
#   104,
#   76,
#   72,
#   71,
#   54,
#   53,
#   59,
#   81,
#   72,
#   74,
#   94,
#   84,
#   69,
#   76,
#   74,
#   66,
#   63,
#   72,
#   77,
#   50,
#   67,
#   71,
#   86,
#   63,
#   66,
#   63,
#   42,
#   58,
#   59,
#   79,
#   70,
#   56,
#   51,
#   64,
#   52,
#   69,
#   79,
#   67,
#   54,
#   65,
#   65,
#   59,
#   64,
#   77,
#   64,
#   61,
#   53,
#   69,
#   88,
#   62,
#   82,
#   42,
#   39,
#   46,
#   42,
#   79],
#  'Palästinakrieg': [198,
#   184,
#   286,
#   426,
#   336,
#   215,
#   278,
#   334,
#   2039,
#   364,
#   238,
#   213,
#   206,
#   234,
#   170,
#   199,
#   264,
#   229,
#   244,
#   291,
#   209,
#   194,
#   216,
#   304,
#   308,
#   239,
#   207,
#   173,
#   178,
#   188,
#   212,
#   215,
#   187,
#   170,
#   220,
#   164,
#   214,
#   228,
#   196,
#   190,
#   197,
#   177,
#   164,
#   222,
#   207,
#   257,
#   225,
#   251,
#   186,
#   189,
#   197,
#   175,
#   194,
#   164,
#   172,
#   218,
#   171,
#   221,
#   246,
#   209,
#   201,
#   166,
#   151,
#   185,
#   158,
#   188,
#   269,
#   185,
#   161,
#   259,
#   173,
#   191,
#   182,
#   207,
#   251,
#   191,
#   168,
#   179,
#   375,
#   205,
#   196,
#   200,
#   198,
#   167,
#   170,
#   205,
#   163,
#   181,
#   178,
#   185,
#   169,
#   190,
#   326],
#  'Muslim': [189,
#   254,
#   196,
#   200,
#   210,
#   298,
#   147,
#   156,
#   215,
#   193,
#   194,
#   184,
#   187,
#   197,
#   148,
#   190,
#   179,
#   181,
#   180,
#   179,
#   188,
#   159,
#   224,
#   215,
#   260,
#   232,
#   242,
#   190,
#   180,
#   198,
#   184,
#   174,
#   162,
#   174,
#   205,
#   182,
#   163,
#   199,
#   167,
#   184,
#   200,
#   144,
#   184,
#   196,
#   168,
#   173,
#   169,
#   181,
#   149,
#   142,
#   190,
#   222,
#   148,
#   188,
#   174,
#   188,
#   193,
#   215,
#   204,
#   222,
#   177,
#   176,
#   195,
#   167,
#   204,
#   184,
#   186,
#   191,
#   159,
#   154,
#   172,
#   175,
#   350,
#   383,
#   237,
#   251,
#   281,
#   206,
#   190,
#   204,
#   197,
#   199,
#   337,
#   213,
#   175,
#   225,
#   200,
#   183,
#   169,
#   227,
#   206,
#   167,
#   189],
#  'Araber': [162,
#   225,
#   196,
#   191,
#   158,
#   168,
#   163,
#   138,
#   194,
#   184,
#   168,
#   197,
#   207,
#   230,
#   163,
#   228,
#   202,
#   208,
#   176,
#   158,
#   232,
#   212,
#   225,
#   214,
#   217,
#   177,
#   150,
#   181,
#   170,
#   202,
#   175,
#   191,
#   156,
#   176,
#   165,
#   159,
#   219,
#   175,
#   185,
#   188,
#   162,
#   153,
#   190,
#   185,
#   179,
#   189,
#   220,
#   206,
#   210,
#   185,
#   208,
#   211,
#   197,
#   203,
#   217,
#   165,
#   168,
#   238,
#   160,
#   166,
#   182,
#   135,
#   144,
#   131,
#   235,
#   179,
#   159,
#   143,
#   163,
#   168,
#   179,
#   195,
#   178,
#   240,
#   197,
#   180,
#   170,
#   167,
#   230,
#   190,
#   170,
#   178,
#   173,
#   151,
#   167,
#   150,
#   167,
#   141,
#   141,
#   143,
#   160,
#   143,
#   172],
#  'Palästinensische Autonomiegebiete': [127,
#   152,
#   379,
#   453,
#   363,
#   224,
#   196,
#   162,
#   219,
#   195,
#   191,
#   187,
#   193,
#   165,
#   123,
#   209,
#   216,
#   230,
#   246,
#   150,
#   166,
#   124,
#   166,
#   175,
#   206,
#   176,
#   151,
#   138,
#   165,
#   151,
#   153,
#   149,
#   168,
#   142,
#   163,
#   130,
#   172,
#   220,
#   125,
#   134,
#   142,
#   127,
#   148,
#   171,
#   159,
#   175,
#   139,
#   174,
#   134,
#   133,
#   147,
#   172,
#   186,
#   226,
#   268,
#   213,
#   127,
#   165,
#   209,
#   171,
#   122,
#   142,
#   141,
#   152,
#   150,
#   155,
#   174,
#   175,
#   137,
#   135,
#   142,
#   151,
#   160,
#   166,
#   336,
#   145,
#   155,
#   132,
#   161,
#   164,
#   159,
#   188,
#   162,
#   125,
#   134,
#   164,
#   133,
#   166,
#   124,
#   121,
#   122,
#   114,
#   147],
#  'Palästinensische Autonomiebehörde': [35,
#   43,
#   127,
#   158,
#   111,
#   60,
#   65,
#   53,
#   60,
#   51,
#   65,
#   59,
#   39,
#   46,
#   42,
#   73,
#   62,
#   61,
#   41,
#   41,
#   48,
#   23,
#   55,
#   57,
#   48,
#   44,
#   43,
#   35,
#   33,
#   43,
#   33,
#   32,
#   36,
#   34,
#   40,
#   43,
#   45,
#   62,
#   42,
#   57,
#   32,
#   35,
#   23,
#   54,
#   48,
#   48,
#   43,
#   47,
#   46,
#   42,
#   40,
#   37,
#   37,
#   53,
#   39,
#   35,
#   49,
#   33,
#   44,
#   37,
#   25,
#   61,
#   28,
#   28,
#   32,
#   34,
#   45,
#   42,
#   50,
#   40,
#   27,
#   31,
#   31,
#   79,
#   108,
#   43,
#   58,
#   46,
#   59,
#   50,
#   49,
#   37,
#   40,
#   46,
#   37,
#   40,
#   49,
#   46,
#   39,
#   34,
#   30,
#   25,
#   31],
#  'Fatah-Hamas-Konflikt': [23,
#   22,
#   40,
#   29,
#   36,
#   20,
#   24,
#   16,
#   27,
#   29,
#   22,
#   17,
#   17,
#   20,
#   15,
#   27,
#   11,
#   17,
#   20,
#   25,
#   28,
#   14,
#   24,
#   22,
#   21,
#   10,
#   26,
#   19,
#   9,
#   33,
#   57,
#   28,
#   14,
#   26,
#   29,
#   16,
#   18,
#   25,
#   19,
#   18,
#   16,
#   16,
#   12,
#   21,
#   17,
#   23,
#   23,
#   15,
#   15,
#   13,
#   22,
#   19,
#   16,
#   14,
#   22,
#   8,
#   19,
#   17,
#   22,
#   21,
#   15,
#   18,
#   20,
#   17,
#   18,
#   12,
#   23,
#   22,
#   17,
#   11,
#   12,
#   25,
#   25,
#   24,
#   33,
#   32,
#   19,
#   16,
#   17,
#   20,
#   18,
#   20,
#   11,
#   19,
#   15,
#   17,
#   19,
#   26,
#   16,
#   17,
#   13,
#   13,
#   22],
#  'Westjordanland': [445,
#   376,
#   3116,
#   3577,
#   1982,
#   746,
#   618,
#   606,
#   611,
#   464,
#   454,
#   495,
#   414,
#   409,
#   321,
#   517,
#   675,
#   547,
#   474,
#   363,
#   364,
#   341,
#   426,
#   453,
#   505,
#   508,
#   372,
#   281,
#   386,
#   468,
#   360,
#   392,
#   384,
#   358,
#   320,
#   312,
#   453,
#   434,
#   346,
#   341,
#   365,
#   255,
#   245,
#   360,
#   305,
#   431,
#   343,
#   345,
#   294,
#   345,
#   357,
#   329,
#   355,
#   352,
#   293,
#   378,
#   270,
#   365,
#   303,
#   289,
#   253,
#   292,
#   242,
#   247,
#   303,
#   306,
#   319,
#   321,
#   317,
#   286,
#   252,
#   285,
#   308,
#   330,
#   429,
#   316,
#   249,
#   255,
#   348,
#   338,
#   331,
#   368,
#   265,
#   256,
#   284,
#   359,
#   306,
#   316,
#   242,
#   244,
#   239,
#   233,
#   354],
#  'Hamas': [146,
#   148,
#   272,
#   427,
#   346,
#   217,
#   161,
#   169,
#   164,
#   163,
#   177,
#   172,
#   125,
#   124,
#   101,
#   181,
#   177,
#   170,
#   165,
#   121,
#   147,
#   113,
#   171,
#   191,
#   236,
#   194,
#   164,
#   143,
#   143,
#   175,
#   230,
#   196,
#   160,
#   167,
#   179,
#   131,
#   214,
#   359,
#   131,
#   151,
#   131,
#   109,
#   123,
#   152,
#   174,
#   144,
#   137,
#   207,
#   166,
#   116,
#   142,
#   133,
#   107,
#   131,
#   139,
#   128,
#   122,
#   137,
#   165,
#   292,
#   165,
#   124,
#   145,
#   129,
#   115,
#   122,
#   141,
#   159,
#   136,
#   123,
#   111,
#   137,
#   150,
#   182,
#   222,
#   166,
#   170,
#   141,
#   159,
#   142,
#   167,
#   139,
#   123,
#   133,
#   102,
#   151,
#   138,
#   129,
#   132,
#   123,
#   112,
#   93,
#   111],
#  'Terroristische Vereinigung': [65,
#   73,
#   95,
#   63,
#   69,
#   76,
#   50,
#   49,
#   63,
#   76,
#   73,
#   72,
#   99,
#   93,
#   52,
#   70,
#   84,
#   55,
#   81,
#   67,
#   56,
#   64,
#   65,
#   73,
#   86,
#   55,
#   63,
#   59,
#   42,
#   43,
#   49,
#   46,
#   45,
#   47,
#   51,
#   47,
#   48,
#   43,
#   61,
#   69,
#   55,
#   68,
#   61,
#   79,
#   61,
#   56,
#   69,
#   76,
#   45,
#   31,
#   59,
#   88,
#   80,
#   68,
#   64,
#   56,
#   58,
#   72,
#   66,
#   55,
#   185,
#   91,
#   91,
#   60,
#   85,
#   85,
#   82,
#   157,
#   85,
#   69,
#   70,
#   102,
#   100,
#   81,
#   100,
#   99,
#   78,
#   75,
#   84,
#   110,
#   97,
#   92,
#   105,
#   80,
#   69,
#   69,
#   90,
#   69,
#   67,
#   66,
#   50,
#   54,
#   121],
#  'Personenverkehr': [26,
#   10,
#   25,
#   44,
#   28,
#   15,
#   25,
#   20,
#   22,
#   21,
#   15,
#   19,
#   15,
#   18,
#   11,
#   9,
#   14,
#   15,
#   16,
#   26,
#   11,
#   13,
#   16,
#   33,
#   22,
#   26,
#   19,
#   13,
#   14,
#   15,
#   24,
#   14,
#   18,
#   18,
#   13,
#   12,
#   15,
#   20,
#   19,
#   20,
#   16,
#   22,
#   9,
#   25,
#   21,
#   20,
#   24,
#   26,
#   19,
#   11,
#   14,
#   22,
#   18,
#   12,
#   23,
#   18,
#   10,
#   21,
#   15,
#   14,
#   23,
#   24,
#   17,
#   10,
#   19,
#   11,
#   28,
#   27,
#   21,
#   15,
#   16,
#   9,
#   20,
#   15,
#   24,
#   15,
#   26,
#   17,
#   16,
#   16,
#   22,
#   22,
#   29,
#   33,
#   18,
#   10,
#   14,
#   21,
#   22,
#   16,
#   20,
#   21,
#   12],
#  'Europäische Union': [1545,
#   1666,
#   1929,
#   1866,
#   1666,
#   1560,
#   1574,
#   1295,
#   1514,
#   3355,
#   2670,
#   2218,
#   1977,
#   1653,
#   1429,
#   1598,
#   1789,
#   1739,
#   1749,
#   1904,
#   1539,
#   1377,
#   1628,
#   1708,
#   1709,
#   1582,
#   1550,
#   1582,
#   1515,
#   1531,
#   1711,
#   1650,
#   1511,
#   1646,
#   1476,
#   1261,
#   1868,
#   1833,
#   1876,
#   1930,
#   1848,
#   1740,
#   1439,
#   1691,
#   1784,
#   1809,
#   1876,
#   1742,
#   1582,
#   1375,
#   1588,
#   1922,
#   2276,
#   2047,
#   2041,
#   2347,
#   1794,
#   1877,
#   1964,
#   2151,
#   2015,
#   1913,
#   1674,
#   1337,
#   1656,
#   2133,
#   2103,
#   2003,
#   2103,
#   1901,
#   1643,
#   1773,
#   2074,
#   2078,
#   2481,
#   2445,
#   1985,
#   1451,
#   1836,
#   2139,
#   2197,
#   2752,
#   2119,
#   1964,
#   1366,
#   1753,
#   2120,
#   2147,
#   2024,
#   1862,
#   2002,
#   1767,
#   2158],
#  'Sand': [138,
#   143,
#   200,
#   171,
#   189,
#   161,
#   139,
#   147,
#   166,
#   170,
#   175,
#   164,
#   151,
#   174,
#   130,
#   132,
#   152,
#   162,
#   138,
#   126,
#   148,
#   118,
#   128,
#   135,
#   160,
#   143,
#   166,
#   141,
#   133,
#   128,
#   152,
#   177,
#   164,
#   135,
#   137,
#   109,
#   168,
#   144,
#   175,
#   135,
#   170,
#   139,
#   108,
#   119,
#   128,
#   152,
#   162,
#   167,
#   133,
#   102,
#   141,
#   161,
#   171,
#   203,
#   148,
#   170,
#   136,
#   128,
#   133,
#   195,
#   193,
#   169,
#   172,
#   100,
#   149,
#   164,
#   176,
#   202,
#   173,
#   154,
#   172,
#   168,
#   156,
#   202,
#   169,
#   176,
#   189,
#   130,
#   178,
#   155,
#   166,
#   155,
#   175,
#   129,
#   129,
#   156,
#   169,
#   160,
#   152,
#   203,
#   146,
#   106,
#   158],
#  'Düne': [63,
#   62,
#   71,
#   62,
#   81,
#   78,
#   75,
#   67,
#   65,
#   56,
#   97,
#   68,
#   60,
#   57,
#   55,
#   84,
#   73,
#   87,
#   81,
#   71,
#   64,
#   67,
#   68,
#   95,
#   82,
#   73,
#   78,
#   74,
#   78,
#   86,
#   80,
#   59,
#   74,
#   64,
#   59,
#   68,
#   73,
#   82,
#   82,
#   75,
#   82,
#   77,
#   52,
#   93,
#   78,
#   73,
#   91,
#   69,
#   58,
#   63,
#   74,
#   74,
#   90,
#   78,
#   73,
#   57,
#   67,
#   83,
#   71,
#   74,
#   90,
#   59,
#   60,
#   53,
#   86,
#   66,
#   69,
#   60,
#   71,
#   59,
#   43,
#   42,
#   67,
#   59,
#   64,
#   70,
#   46,
#   43,
#   61,
#   72,
#   55,
#   71,
#   60,
#   46,
#   55,
#   54,
#   31,
#   60,
#   53,
#   55,
#   62,
#   52,
#   58],
#  'Landwirtschaft': [104,
#   167,
#   199,
#   172,
#   150,
#   176,
#   136,
#   94,
#   150,
#   157,
#   159,
#   153,
#   143,
#   171,
#   102,
#   159,
#   137,
#   152,
#   165,
#   154,
#   102,
#   107,
#   110,
#   131,
#   154,
#   147,
#   153,
#   127,
#   96,
#   130,
#   143,
#   103,
#   106,
#   124,
#   111,
#   110,
#   155,
#   143,
#   148,
#   143,
#   117,
#   122,
#   104,
#   114,
#   140,
#   162,
#   171,
#   159,
#   126,
#   85,
#   133,
#   197,
#   199,
#   182,
#   156,
#   147,
#   137,
#   146,
#   170,
#   210,
#   162,
#   165,
#   141,
#   127,
#   150,
#   184,
#   175,
#   166,
#   161,
#   135,
#   139,
#   137,
#   149,
#   171,
#   183,
#   181,
#   173,
#   117,
#   134,
#   171,
#   204,
#   178,
#   155,
#   151,
#   121,
#   133,
#   215,
#   193,
#   209,
#   180,
#   132,
#   88,
#   124],
#  'Abu Auda': [2,
#   0,
#   2,
#   1,
#   4,
#   0,
#   4,
#   2,
#   3,
#   1,
#   4,
#   1,
#   1,
#   1,
#   0,
#   2,
#   0,
#   0,
#   1,
#   0,
#   1,
#   1,
#   1,
#   1,
#   1,
#   2,
#   5,
#   0,
#   0,
#   1,
#   1,
#   5,
#   1,
#   4,
#   1,
#   2,
#   0,
#   0,
#   1,
#   1,
#   1,
#   2,
#   1,
#   1,
#   0,
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   2,
#   2,
#   1,
#   0,
#   2,
#   0,
#   1,
#   1,
#   0,
#   1,
#   0,
#   1,
#   1,
#   1,
#   0,
#   0,
#   1,
#   2,
#   3,
#   2,
#   1,
#   2,
#   0,
#   2,
#   1,
#   0,
#   0,
#   2,
#   2,
#   3]}
